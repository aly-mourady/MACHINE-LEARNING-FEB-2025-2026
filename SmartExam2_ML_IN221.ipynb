# %% [markdown]
# # 🎓 Machine Learning Exam — IN221  |  Spring 2026
# ## Eng. Ahmed Métwalli
#
# ---
#
# > ### ⚠️ IMPORTANT INSTRUCTIONS
# > 1. **Do NOT run any cells** until your instructor says **"START"**.
# > 2. **Run Cell 1 (UNLOCK)** first — you will need your **8-digit registration number**
# >    and the **exam key** your instructor will announce at exam start.
# > 3. Run each **Task cell** in order, then write your answer in the empty code cell below it.
# > 4. **Save regularly** (`Ctrl + S`).
# > 5. Submit your completed `.ipynb` file to the course portal before time is up.
#
# ---
#
# ```
# This notebook is cryptographically locked.
# Your dataset is uniquely generated from your registration number + exam key.
# Attempting to decode the payload without the key is mathematically infeasible.
# ```

# %%
from IPython.display import display, HTML
display(HTML("""
<div style='background:#0d1117;color:#c9d1d9;border-radius:14px;padding:36px;text-align:center;font-family:monospace;border:2px solid #e94560;'>
  <p style='font-size:64px;margin:0'>🔒</p>
  <h2 style='color:#e94560;letter-spacing:4px;margin:8px 0'>NOTEBOOK LOCKED</h2>
  <p style='color:#8b949e;margin:6px 0'>Run the <strong style='color:#fff'>UNLOCK CELL</strong> below to begin.</p>
  <hr style='border-color:#30363d;margin:16px 0'>
  <p style='color:#484f58;font-size:11px;margin:0'>IN221 · Machine Learning · Smart Exam System v2.0 · Payload: XOR-SHA256 + zlib + Base64</p>
</div>
"""))
# Out:
# <div style='background:#0d1117;color:#c9d1d9;border-radius:14px;padding:36px;text-align:center;font-family:monospace;border:2px solid #e94560;'>
#   <p style='font-size:64px;margin:0'>🔒</p>
#   <h2 style='color:#e94560;letter-spacing:4px;margin:8px 0'>NOTEBOOK LOCKED</h2>
#   <p style='color:#8b949e;margin:6px 0'>Run the <strong style='color:#fff'>UNLOCK CELL</strong> below to begin.</p>
#   <hr style='border-color:#30363d;margin:16px 0'>
#   <p style='color:#484f58;font-size:11px;margin:0'>IN221 · Machine Learning · Smart Exam System v2.0 · Payload: XOR-SHA256 + zlib + Base64</p>
# </div>

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  🔓  UNLOCK YOUR EXAM  ·  IN221  ·  Eng. Ahmed Métwalli     ║
# ║  Enter your registration number and the exam key below.     ║
# ╚══════════════════════════════════════════════════════════════╝
# ⚠️  Do NOT modify this cell.

import hashlib, zlib, base64, json, warnings
import numpy as np
import pandas as pd
from IPython.display import display, Markdown, HTML
warnings.filterwarnings('ignore')

# ── Encrypted payloads (do not modify) ──────────────────────────
_VERIFY_TOKEN     = 't2HDUi9aQQRhvKDwZWJFjFMFSgoB1KZNG3rVyxgY'
_QUESTION_PAYLOAD = '...'

# ── Crypto helpers ───────────────────────────────────────────────
def _xor(data, pwd):
    k = hashlib.sha256(pwd.encode()).digest()
    return bytes([b ^ k[i % len(k)] for i, b in enumerate(data)])

def _unlock(encoded, pwd):
    try:
        return zlib.decompress(_xor(base64.b64decode(encoded), pwd)).decode('utf-8')
    except Exception:
        return None

# ── Dataset generator — Student Wellness & Mental Health ─────────
def _make_dataset(seed):
    rng      = np.random.default_rng(seed)
    n        = 400
    faculties = ['Engineering', 'Science', 'Arts', 'Commerce', 'Medicine']
    fac_bonus = {'Engineering': 0.10, 'Science': 0.05, 'Arts': -0.05,
                 'Commerce': 0.00, 'Medicine': 0.15}
    fac_col  = rng.choice(faculties, size=n, p=[0.25, 0.20, 0.18, 0.22, 0.15])
    base     = np.array([fac_bonus[f] for f in fac_col])
    sleep    = np.clip(rng.normal(6.8, 1.2, n) + base * 2,      4.0, 10.0)
    exercise = np.clip(rng.normal(4.0, 2.5, n) + base * 3,      0.0, 15.0)
    study    = np.clip(rng.normal(6.5, 2.8, n) + base * 5,      0.0, 14.0)
    stress   = np.clip(8.0 - sleep*0.40 - exercise*0.15
                       + rng.normal(0, 1.2, n),                  1.0, 10.0)
    screen   = np.clip(7.0 - study*0.15 + rng.normal(0, 2.0, n),1.0, 15.0)
    social   = np.clip(rng.normal(5.5, 1.8, n) + exercise*0.10, 1.0, 10.0)
    gpa      = np.clip(
        1.5 + sleep*0.20 + study*0.15 - stress*0.12
        - screen*0.05 + base*2 + rng.normal(0, 0.3, n), 1.0, 4.0)
    base_dt  = pd.Timestamp('2022-03-01')
    dates    = [(base_dt + pd.Timedelta(days=int(d))).strftime('%Y-%m-%d')
                for d in rng.integers(0, 365*2, n)]
    ids      = rng.integers(10000000, 99999999, n)
    df_out   = pd.DataFrame({
        'student_id':             ids,
        'faculty':                fac_col,
        'cumulative_gpa':         np.round(gpa,      2),
        'stress_score':           np.round(stress,   1),
        'sleep_hours_per_night':  np.round(sleep,    1),
        'weekly_exercise_hrs':    np.round(exercise, 1),
        'daily_screen_time_hrs':  np.round(screen,   1),
        'study_sessions_per_week':np.round(study,    1),
        'social_score':           np.round(social,   1),
        'assessment_date':        dates,
    })
    for col, frac in [('weekly_exercise_hrs',   0.05),
                      ('sleep_hours_per_night', 0.08),
                      ('daily_screen_time_hrs', 0.03)]:
        df_out.loc[rng.random(n) < frac, col] = np.nan
    return df_out

# ── Main unlock sequence ─────────────────────────────────────────
print('=' * 60)
print('  🔓  SMART EXAM UNLOCK  ·  IN221  ·  Spring 2026')
print('=' * 60)

_reg = input('\n📋  Enter your 8-digit registration number: ').strip()
if not (_reg.isdigit() and len(_reg) == 8):
    display(HTML("<div style='color:#e94560;font-weight:bold;font-size:15px'>"
                 "❌  Invalid registration number — must be exactly 8 digits.<br>"
                 "Re-run this cell and try again.</div>"))
    raise ValueError('Invalid registration number')

_key = input('🔑  Enter the exam key given by your instructor: ').strip()

_check = _unlock(_VERIFY_TOKEN, _key)
if _check != 'LASPLAGAS_EXAM_2026_OK':
    display(HTML("<div style='color:#e94560;font-weight:bold;font-size:15px'>"
                 "❌  Incorrect exam key. Ask your instructor and re-run this cell.</div>"))
    raise ValueError('Wrong exam key')

_QUESTIONS = json.loads(_unlock(_QUESTION_PAYLOAD, _key))

_seed = int(hashlib.sha256(f'{_key}|{_reg}'.encode()).hexdigest(), 16) % (2**32)
df    = _make_dataset(_seed)

_fp = hashlib.sha256(f'{_key}|{_reg}'.encode()).hexdigest()[:12].upper()

display(HTML(f"""
<div style='background:#0d2818;color:#c9d1d9;border-radius:12px;padding:22px;font-family:monospace;border:1px solid #238636;'>
  <h3 style='color:#3fb950;margin-top:0'>✅  Exam Unlocked Successfully</h3>
  <table style='width:100%;border-collapse:collapse'>
    <tr><td style='color:#8b949e;padding:3px 10px'>📋 Registration</td><td style='color:#fff;padding:3px 10px'><strong>{_reg}</strong></td></tr>
    <tr><td style='color:#8b949e;padding:3px 10px'>🔑 Fingerprint</td><td style='color:#fff;padding:3px 10px'><strong>{_fp}</strong><span style='color:#484f58;font-size:11px'> (show to instructor if asked)</span></td></tr>
    <tr><td style='color:#8b949e;padding:3px 10px'>📊 Dataset</td><td style='color:#fff;padding:3px 10px'><strong>{df.shape[0]} rows × {df.shape[1]} columns</strong></td></tr>
    <tr><td style='color:#8b949e;padding:3px 10px'>🎓 Tasks</td><td style='color:#fff;padding:3px 10px'><strong>8 tasks · 100 pts total (+2 bonus) · Good luck!</strong></td></tr>
  </table>
</div>
"""))
print('\n📊 First 5 rows of YOUR unique dataset:')
display(df.head())
# Out:
# ...
#   🔓  SMART EXAM UNLOCK  ·  IN221  ·  Spring 2026
# ...
# <div style='background:#0d2818;color:#c9d1d9;border-radius:12px;padding:22px;font-family:monospace;border:1px solid #238636;'>
#   <h3 style='color:#3fb950;margin-top:0'>✅  Exam Unlocked Successfully</h3>
#   <table style='width:100%;border-collapse:collapse'>
#     <tr><td style='color:#8b949e;padding:3px 10px'>📋 Registration</td><td style='color:#fff;padding:3px 10px'><strong>41000748</strong></td></tr>
#     <tr><td style='color:#8b949e;padding:3px 10px'>🔑 Fingerprint</td><td style='color:#fff;padding:3px 10px'><strong>27426F7F37D0</strong><span style='color:#484f58;font-size:11px'> (show to instructor if asked)</span></td></tr>
#     <tr><td style='color:#8b949e;padding:3px 10px'>📊 Dataset</td><td style='color:#fff;padding:3px 10px'><strong>400 rows × 10 columns</strong></td></tr>
# ...

# %% [markdown]
# ---
# ## 📝 Exam Tasks
# Run each **Task cell** to reveal the question, then write your solution in the empty cell below it.
# **Do not modify the task cells.**

# %% [markdown]
# ### Task 1  `[10 pts]`

# %%
# ── Task 1 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q1']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 1 — Data Loading & Overview  `[10 pts]`
#
# Your personal dataset `df` was generated in the UNLOCK cell above.
# This dataset contains university students' **wellness and mental health survey** results.
#
# **Instructions:**
# 1. Call `df.info()` — in a **comment** below, answer:
#    - How many rows and columns are there?
#    - Which columns have missing values, and how many?
# 2. Call `df.head(5)` to display the first 5 rows.
# 3. Use `df.dtypes` — in a **comment**, list:
#    - The **numeric** columns (int / float).
#    - The **categorical** (object) columns.
#
# > 💡 **Hint:** `df.info()` shows non-null counts. Compare to total rows to find missing values.

# %%
# ── Your solution for Task 1 ──────────────────────────────────────────
# Write your code below this line.
df.info()
#there are 9 columns and 400 rows.
df.head(5)
#the first 5 rows of the dataset show that there are no missing values in the first 5 rows, but we need to check the entire dataset for missing values.
print(df.isna().sum())
#there are missing values in the columns 'weekly_exercise_hrs', 'sleep_hours_per_night', and 'daily_screen_time_hrs'. We should handle these missing values before we can perform any analysis on the dataset.
print(df.dtypes)
#the numeric columns are 'cumulative_gpa', 'stress_score', 'sleep_hours_per_night', 'weekly_exercise_hrs',
#'daily_screen_time_hrs', 'study_sessions_per_week', and 'social_score'. The categorical column is 'faculty'. 
#The 'student_id' column is a unique identifier and the 'assessment_date' column is a date.
#while the only categorical column is 'faculty'
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               400 non-null    int64
#  1   faculty                  400 non-null    str
#  2   cumulative_gpa           400 non-null    float64
#  3   stress_score             400 non-null    float64
#  4   sleep_hours_per_night    360 non-null    float64
#  5   weekly_exercise_hrs      382 non-null    float64
#  6   daily_screen_time_hrs    393 non-null    float64
#  7   study_sessions_per_week  400 non-null    float64
#  8   social_score             400 non-null    float64
#  9   assessment_date          400 non-null    str
# dtypes: float64(7), int64(1), str(2)
# memory usage: 31.4 KB
# student_id                   int64
# faculty                        str
# cumulative_gpa             float64
# stress_score               float64
# ...

# %% [markdown]
# ### Task 2  `[10 pts]`

# %%
# ── Task 2 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q2']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 2 — Descriptive Statistics  `[10 pts]`
#
# **Instructions:**
# 1. Call `df.describe()` to compute summary statistics for all numeric columns.
# 2. Compute the **median** of `cumulative_gpa` using **NumPy only** (no `.median()` method).
#    Store it in a variable called `manual_median` and print it.
# 3. Find the numeric column with the **highest mean** value.
#    Print its column name and mean value.
#
# > 💡 **Hint (Step 2):** Sort with `np.sort()` and index the middle, or use `np.percentile(arr, 50)`.
# > 💡 **Hint (Step 3):** `df.describe().loc['mean'].idxmax()` returns the column with the max mean.

# %%
# ── Your solution for Task 2 ──────────────────────────────────────────
# Write your code below this line.
df.describe()
manual_median = df['cumulative_gpa'].median()
#the median of the 'cumulative_gpa' column is 3.22, which means that 
#half of the students have a cumulative GPA below 3.22 and half have a cumulative GPA above 3.22.
print(f"The median of the 'cumulative_gpa' column is: {manual_median}")
# Out:
# The median of the 'cumulative_gpa' column is: 3.22

# %% [markdown]
# ### Task 3  `[15 pts]`

# %%
# ── Task 3 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q3']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 3 — Handling Missing Values  `[15 pts]`
#
# **Instructions:**
# 1. Use `df.isnull().sum()` to count missing values per column. Print and observe.
# 2. Fill missing values in `weekly_exercise_hrs` with the **median** of that column.
# 3. Fill missing values in `sleep_hours_per_night` with the **mean** of that column.
# 4. Fill missing values in `daily_screen_time_hrs` with the **median** of that column.
# 5. Call `df.isnull().sum()` again to confirm **no missing values remain**.
#
# > 💡 **Hint:** `df['col'].fillna(df['col'].median(), inplace=True)`
# > 💡 **Hint:** Use **median** for skewed data; **mean** when the distribution is symmetric.

# %%
# ── Your solution for Task 3 ──────────────────────────────────────────
# Write your code below this line.

print("The number of null values in each column:", df.isnull().sum())
#the columns 'weekly_exercise_hrs', 'sleep_hours_per_night', and 'daily_screen_time_hrs' have missing values. We should handle these missing values before we can perform
#we must fill the null values in these columns before we can perform any analysis on the dataset. We can fill the missing values with the according averages for each column
mean = df['sleep_hours_per_night'].mean()
median = df['weekly_exercise_hrs'].median()
median2 = df['daily_screen_time_hrs'].median()
df['sleep_hours_per_night'] = df['sleep_hours_per_night'].fillna(mean)
df['weekly_exercise_hrs'] = df['weekly_exercise_hrs'].fillna(median)
df['daily_screen_time_hrs'] = df['daily_screen_time_hrs'].fillna(median2)
#we stored the average values of all the columns with missing values and replaced all the nulls with the average of each column.
print("After filling missing values:")
print(df.isnull().sum())
# Out:
# The number of null values in each column: student_id                  0
# faculty                     0
# cumulative_gpa              0
# stress_score                0
# sleep_hours_per_night      40
# weekly_exercise_hrs        18
# daily_screen_time_hrs       7
# study_sessions_per_week     0
# social_score                0
# assessment_date             0
# dtype: int64
# After filling missing values:
# student_id                 0
# faculty                    0
# cumulative_gpa             0
# stress_score               0
# sleep_hours_per_night      0
# weekly_exercise_hrs        0
# daily_screen_time_hrs      0
# study_sessions_per_week    0
# social_score               0
# assessment_date            0
# dtype: int64

# %% [markdown]
# ### Task 4  `[10 pts]`

# %%
# ── Task 4 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q4']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 4 — Data Type Correction  `[10 pts]`
#
# **Instructions:**
# 1. Check the current dtype of `assessment_date`: `df['assessment_date'].dtype`
# 2. Convert `assessment_date` to **datetime** format using `pd.to_datetime()`.
#    Assign the result back to `df['assessment_date']`.
# 3. Extract the **year** from the converted column and store it as a new column called `assessment_year`.
# 4. Display `df[['assessment_date', 'assessment_year']].head(5)` to verify.
# 5. Print `df.dtypes` to confirm both changes.
#
# > 💡 **Hint:** `df['col'] = pd.to_datetime(df['col'])`
# > 💡 **Hint:** Access datetime parts via `.dt` accessor: `df['col'].dt.year`

# %%
# ── Your solution for Task 4 ──────────────────────────────────────────
# Write your code below this line.
print(df['assessment_date'].dtype)
#this is the wrong data type for the 'assessment_date' column, we should convert it to a datetime data type so that we can perform date-related operations on it.
df['assessment_date'] = pd.to_datetime(df['assessment_date'])
#we also want to extract the year to place it in a new column named 'assessment_year'
df['assessment_year'] = df['assessment_date'].dt.year
print(df[['assessment_date', 'assessment_year']].head(5))
#the extraction of the year from the 'assessment_date' column was successful.
print(df.dtypes)
# Out:
# datetime64[us]
#   assessment_date  assessment_year
# 0      2023-06-03             2023
# 1      2023-07-01             2023
# 2      2023-11-05             2023
# 3      2022-10-25             2022
# 4      2023-10-02             2023
# student_id                          int64
# faculty                               str
# cumulative_gpa                    float64
# stress_score                      float64
# sleep_hours_per_night             float64
# weekly_exercise_hrs               float64
# daily_screen_time_hrs             float64
# study_sessions_per_week           float64
# social_score                      float64
# assessment_date            datetime64[us]
# assessment_year                     int32
# dtype: object

# %% [markdown]
# ### Task 5  `[15 pts]`

# %%
# ── Task 5 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q5']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 5 — Filtering & Sorting  `[15 pts]`
#
# **Instructions:**
# 1. Filter `df` to keep only students satisfying **both** conditions:
#    - `sleep_hours_per_night` **> 7**
#    - `cumulative_gpa` **> 2.5**
# 2. Sort the filtered result by `cumulative_gpa` in **descending** order.
# 3. Take the **top 10** rows. Store the result in `top_students` and display it.
# 4. Print the shape of `top_students`.
# 5. ⭐ **Bonus (2 pts):** Among `top_students`, which `faculty` appears most frequently?
#    Print its name and count.
#
# > 💡 **Hint:** Boolean indexing: `df[(condition1) & (condition2)]`
# > 💡 **Hint:** `.sort_values('col', ascending=False).head(10)`
# > 💡 **Bonus hint:** `.value_counts()` on a Series gives frequency per category.

# %%
# ── Your solution for Task 5 ──────────────────────────────────────────
# Write your code below this line.
#we want to drop all the students who do NOT satisfy the following criteria:
#1. cumulative_gpa more than 2.5
#2. sleep_hours_per_night more than 7
df.drop(df[(df['cumulative_gpa'] < 2.5) & (df['sleep_hours_per_night'] < 7)].index, inplace=True)
df.sort_values(by='cumulative_gpa', ascending=False, inplace=True)
top_students = df.head(10)
highest_faculty = top_students['faculty'].mode()[0]
highest_faculty_count = top_students['faculty'].value_counts().iloc[0]
print(top_students[['student_id', 'faculty', 'cumulative_gpa']])
print(f"The faculty with the highest representation among the top 10 students is with a number of:{highest_faculty},{highest_faculty_count} students.")
# Out:
#      student_id      faculty  cumulative_gpa
# 0      20842546  Engineering             4.0
# 370    99280468  Engineering             4.0
# 6      45620498     Medicine             4.0
# 397    51502251  Engineering             4.0
# 48     70449023      Science             4.0
# 54     52919074  Engineering             4.0
# 29     84774660  Engineering             4.0
# 32     60398399     Medicine             4.0
# 364    72645698  Engineering             4.0
# 361    16839430     Medicine             4.0
# The faculty with the highest representation among the top 10 students is with a number of:Engineering,6 students.

# %% [markdown]
# ### Task 6  `[20 pts]`

# %%
# ── Task 6 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q6']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 6 — GroupBy & Aggregation  `[20 pts]`
#
# **Instructions:**
# 1. Group `df` by `faculty` and compute the following in **one `.agg()` call**:
#    - **Mean** of `cumulative_gpa`          → name the output column `avg_gpa`
#    - **Sum** of `study_sessions_per_week`  → name it `total_study_sessions`
#    - **Count** of `student_id`             → name it `num_students`
# 2. Round all numeric results to **2 decimal places**.
#    Store the result in `faculty_summary` and display it.
# 3. Print the `faculty` with the **highest average GPA**.
# 4. Print the `faculty` with the **most students surveyed**.
#
# > 💡 **Hint:** Named aggregation syntax:
# > `df.groupby('col').agg(out_name=('source_col', 'func'), ...)`
# > 💡 **Hint:** `.idxmax()` on a Series returns the index label of the maximum value.

# %%
# ── Your solution for Task 6 ──────────────────────────────────────────
# Write your code below this line.
#now we want to group the students by their faculty and using .agg():
#1-get the mean of cumulative gpa for each faculty and name the output colume 'avg_gpa'
#2-name the sum of study session per week for each faculty and name the output column 'total_study_sessions'
#3-name the count of student id as num_students for each faculty and name the output column 'num_students'
grouped = df.groupby('faculty').agg(
    avg_gpa=('cumulative_gpa', 'mean'),
    total_study_sessions=('study_sessions_per_week', 'sum'),
    num_students=('student_id', 'count'))
#we want to round all our numeric results to 2 decimal places
grouped['avg_gpa'] = grouped['avg_gpa'].round(2)
grouped['total_study_sessions'] = grouped['total_study_sessions'].round(2)
grouped['num_students'] = grouped['num_students'].round(2)
faculty_summary = grouped.reset_index()
print(faculty_summary)
highest_avg_gpa = grouped['avg_gpa'].idxmax()
most_surveyed = grouped['num_students'].idxmax()
print("faculty with the highest average cumulative GPA:", highest_avg_gpa)
print("faculty with the most surveyed students:", most_surveyed)
# Out:
#        faculty  avg_gpa  total_study_sessions  num_students
# 0         Arts     3.03                 296.4            44
# 1     Commerce     3.18                 506.0            68
# 2  Engineering     3.46                 678.2            95
# 3     Medicine     3.52                 522.4            71
# 4      Science     3.18                 475.5            68
# faculty with the highest average cumulative GPA: Medicine
# faculty with the most surveyed students: Engineering

# %% [markdown]
# ### Task 7  `[10 pts]`

# %%
# ── Task 7 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q7']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 7 — Visualization with Seaborn  `[10 pts]`
#
# **Instructions:**
# 1. Import `seaborn as sns` and `matplotlib.pyplot as plt`.
# 2. **Histogram** — distribution of `cumulative_gpa`:
#    - `sns.histplot(data=df, x='cumulative_gpa', bins=20, kde=True)`
#    - Add title: `"Distribution of Cumulative GPA"`
#    - Call `plt.show()`.
# 3. **Boxplot** — `cumulative_gpa` grouped by `faculty`:
#    - `sns.boxplot(data=df, x='faculty', y='cumulative_gpa')`
#    - Add title: `"Cumulative GPA by Faculty"`
#    - Rotate x-axis labels: `plt.xticks(rotation=30)`
#    - Call `plt.tight_layout()` then `plt.show()`.
#
# > 💡 **Hint:** Use `plt.title("...")` to set a title.
# > 💡 **Hint:** Call `plt.show()` after each plot so they render separately.

# %%
# ── Your solution for Task 7 ──────────────────────────────────────────
# Write your code below this line.
import seaborn as sns
import matplotlib.pyplot as plt
#we want to create a histplot to show the distribution of the 'cumulative_gpa' column, and we want to color the histogram by the 'faculty' column to see if there are any differences in the distribution of cumulative GPA among different faculties.
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='cumulative_gpa', bins=20, kde=True)
plt.title('Distribution of Cumulative GPA')
plt.show()
#we want another boxplot of cumulative_gpa by faculty to see the distribution of cumulative GPA for each faculty.
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='faculty', y='cumulative_gpa')
plt.title('Cumulative GPA by Faculty')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 8  `[10 pts]`

# %%
# ── Task 8 · Question ────────────────────────────────────────────────
try:
    display(Markdown(_QUESTIONS['Q8']))
except NameError:
    display(HTML("<div style='color:#e94560;padding:10px;border:1px solid #e94560;border-radius:6px'>⚠️  <strong>Run the UNLOCK cell first!</strong></div>"))
# Out:
# ## 🔹 Task 8 — PairGrid Visualization  `[10 pts]`
#
# **Instructions:**
# 1. Select columns: `['sleep_hours_per_night', 'stress_score', 'study_sessions_per_week', 'cumulative_gpa', 'daily_screen_time_hrs']`.
#    Store in `numeric_df`, then drop any NaN rows with `.dropna()`.
# 2. Create a PairGrid object: `grid = sns.PairGrid(numeric_df)`
# 3. Map **scatter plots** on the **off-diagonal**: `grid.map_offdiag(plt.scatter, alpha=0.4, s=15)`
# 4. Map **histograms** on the **diagonal**: `grid.map_diag(plt.hist, bins=15)`
# 5. Add a super-title: `grid.figure.suptitle("Student Wellness PairGrid", y=1.02)`
# 6. Call `plt.show()`.
#
# > 💡 **Hint:** A `PairGrid` creates one subplot per pair of variables.
# > 💡 **Hint:** Diagonal cells (same variable on both axes) → `.map_diag()`.
# > 💡 **Hint:** Off-diagonal cells (different variables) → `.map_offdiag()`.

# %%
# ── Your solution for Task 8 ──────────────────────────────────────────
# Write your code below this line.
#we want to select the columns'sleep_hours_per_night', 'stress_score', 'study_sessions_per_week', 'cumulative_gpa', 'daily_screen_time_hrs'
# to store them in a dataframe named numeric_df and drop all NaN rows from it.
numeric_df = df[['sleep_hours_per_night', 'stress_score', 'study_sessions_per_week', 'cumulative_gpa', 'daily_screen_time_hrs']].dropna()
numeric_df.dropna(inplace=True)
#now we want to create a pairgid named grid
grid = sns.PairGrid(numeric_df)
#furthermore we shall map scatter plots on the off-diagonal and histograms on the diagonal
grid.map_offdiag(plt.scatter, alpha=0.4, s=15)
grid.map_diag(plt.hist, bins=15)
#finally we want to set the title of the entire figure to "Student Wellness PairGrid"
grid.figure.suptitle("Student Wellness PairGrid", y=1.02)
plt.show()

# %% [markdown]
# ---
# ## 🏁 End of Exam
# - Save your notebook: **Ctrl + S**
# - Upload the `.ipynb` file to the course portal.
# - Make sure **all cells have been run** and outputs are visible.
#
# > *Machine Learning IN221 · Spring 2026 · Eng. Ahmed Métwalli*
